# %%
import pandas as pd

# %%
df1=pd.read_csv("emails.csv")

# %%
df2=pd.read_csv("CAL_fire.csv")
# Out:
# C:\Users\viren\AppData\Local\Temp\ipykernel_20596\1598736112.py:1: DtypeWarning: Columns (13,37,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2=pd.read_csv("CAL_fire.csv")

# %%
df3=pd.read_csv("Soil Nutrients.csv")

# %%
df4=pd.read_csv("India_December_2024_Temperature.csv")

# %%
df5=pd.read_csv("Zomato.csv")

# %%
#1st -  Emails spam or not spam datset

# %%
df1.shape
# Out:
# (5728, 2)

# %%
df1.size
# Out:
# 11456

# %%
df1.head()
# Out:
#                                                 text  spam
# 0  Subject: naturally irresistible your corporate...     1
# 1  Subject: the stock trading gunslinger  fanny i...     1
# 2  Subject: unbelievable new homes made easy  im ...     1
# 3  Subject: 4 color printing special  request add...     1
# 4  Subject: do not have money , get software cds ...     1

# %%
df1.describe()
# Out:
#               spam
# count  5728.000000
# mean      0.238827
# std       0.426404
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
df1['spam'].value_counts()
# Out:
# 0    4360
# 1    1368
# Name: spam, dtype: int64

# %%
#California fire dataset

# %%
df2.shape
# Out:
# (100230, 47)

# %%
df2.head()
# Out:
#    _id  OBJECTID         * Damage  * Street Number  * Street Name  \
# 0    1         1        No Damage           8376.0   Quail Canyon
# 1    2         2  Affected (1-9%)           8402.0   Quail Canyon
# 2    3         3        No Damage           8430.0  Quail Canyon
# 3    4         4        No Damage           3838.0    Putah Creek
# 4    5         5        No Damage           3830.0    Putah Creek
#
#   * Street Type (e.g. road, drive, lane, etc.)  \
# 0                                         Road
# 1                                         Road
# 2                                         Road
# 3                                         Road
# 4                                         Road
#
#   Street Suffix (e.g. apt. 23, blding C)   * City State  Zip Code  ...  \
# 0                                    NaN  Winters    CA       NaN  ...
# 1                                    NaN  Winters    CA       NaN  ...
# ...

# %%
df2.describe()
# Out:
#                  _id       OBJECTID  * Street Number      Zip Code  \
# count  100230.000000  100230.000000     9.581000e+04  47429.000000
# mean    50115.500000   50227.779717     3.886722e+04  46309.699973
# std     28934.053078   29107.678335     5.271695e+06  47467.653484
# min         1.000000       1.000000     0.000000e+00      0.000000
# 25%     25058.250000   25058.250000     7.232500e+02      0.000000
# 50%     50115.500000   50115.500000     4.308500e+03      0.000000
# 75%     75172.750000   75172.750000     1.000300e+04  95667.000000
# max    100230.000000  101221.000000     1.410065e+09  96311.000000
#
#        # Units in Structure (if multi unit)  \
# count                          31184.000000
# mean                               0.433299
# std                               34.608767
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# ...

# %%
#3rd  Soil  Nutrients

# %%
df3.shape
# Out:
# (15400, 19)

# %%
df3.head()
# Out:
#          Name Fertility       Photoperiod  Temperature    Rainfall        pH  \
# 0  Strawberry  Moderate       Day Neutral    20.887923  747.860765  6.571548
# 1  Strawberry  Moderate       Day Neutral    18.062721  711.104329  6.251806
# 2  Strawberry  Moderate  Short Day Period    16.776782  774.038247  6.346916
# 3  Strawberry  Moderate  Short Day Period    14.281000  665.633506  6.259598
# 4  Strawberry  Moderate       Day Neutral    21.444490  806.531455  6.384368
#
#    Light_Hours  Light_Intensity         Rh    Nitrogen  Phosphorus  \
# 0    13.091483       533.762876  91.197196  170.800381  118.670058
# 1    13.063016       505.789101  91.939623  179.290364  121.020244
# 2    12.945927       512.985617  91.387286  181.440732  116.936806
# 3    13.318922       484.860067  91.254598  176.165282  122.233153
# 4    13.312915       512.747307  92.354829  182.935334  126.088234
#
#     Potassium      Yield Category_pH Soil_Type  Season  N_Ratio  P_Ratio  \
# ...

# %%
df3.describe()
# Out:
#         Temperature      Rainfall            pH   Light_Hours  \
# count  15400.000000  15400.000000  15400.000000  15400.000000
# mean      20.801671    948.814222      6.473372      9.459365
# std        4.415164    340.884493      0.449111      2.588466
# min        9.355908    409.927161      4.888871      5.044913
# 25%       17.915142    707.799164      6.245973      7.017129
# 50%       19.929578    846.623453      6.466286      8.985917
# 75%       22.936714   1109.157262      6.697254     12.019180
# max       39.913892   2508.052849      8.023210     15.918024
#
#        Light_Intensity            Rh      Nitrogen    Phosphorus  \
# count     15400.000000  15400.000000  15400.000000  15400.000000
# mean        398.048832     67.117251    142.769483    107.659893
# std         190.512173     19.005233     58.524592     72.778284
# min          69.146572     29.877266     41.725552     13.155191
# 25%         265.438161     53.009874    117.631453     57.627430
# ...

# %%
#4th    India Statewise tempreture variation

# %%
df4.shape
# Out:
# (28, 32)

# %%
df4.head()
# Out:
#                State      Dec 1      Dec 2      Dec 3      Dec 4      Dec 5  \
# 0     Andhra Pradesh  13.212643  10.698105  16.405815   8.497319   6.896153
# 1  Arunachal Pradesh  12.695942  29.566840  31.158805  10.588216  13.709803
# 2              Assam  34.221683  27.610922  19.972000  12.033237  30.886242
# 3              Bihar  10.779094  15.231415  17.850692  29.218902   8.933719
# 4       Chhattisgarh  34.936467   5.651792   5.474914  20.459450  11.042233
#
#        Dec 6      Dec 7      Dec 8      Dec 9  ...     Dec 22     Dec 23  \
# 0  33.514421  26.366592  30.615332  28.771567  ...  28.637420  31.475606
# 1  11.024991  17.130984  31.089233  19.527048  ...  29.458735  32.622218
# 2  18.723383  20.659154  13.357581  18.972698  ...   5.204009  22.686138
# 3   5.955923  22.229581  21.429557  31.569247  ...   7.876851  28.723005
# 4  32.023758  33.792161  16.842981  18.342867  ...  17.991595  25.268479
#
# ...

# %%
df4.describe()
# Out:
#            Dec 1      Dec 2      Dec 3      Dec 4      Dec 5      Dec 6  \
# count  28.000000  28.000000  28.000000  28.000000  28.000000  28.000000
# mean   20.985590  18.992647  18.492685  18.835263  18.149006  19.212183
# std     9.032708   8.935137   7.709608   8.938826   9.064793   9.963056
# min     5.157948   5.651792   5.263997   5.892994   5.293514   5.955923
# 25%    13.083468  12.453681  13.351077  10.560299  11.025384  11.799349
# 50%    20.772720  16.910285  18.391396  18.952598  15.453447  17.024521
# 75%    27.636513  27.896525  23.205073  25.922358  27.662497  29.525686
# max    34.936467  33.550083  31.702260  34.841828  33.399422  33.655716
#
#            Dec 7      Dec 8      Dec 9     Dec 10  ...     Dec 22     Dec 23  \
# count  28.000000  28.000000  28.000000  28.000000  ...  28.000000  28.000000
# mean   23.343182  21.611906  19.740087  20.204809  ...  17.746880  19.788446
# std     8.049505   7.568345   8.942675   8.005237  ...   9.536556   9.731835
# ...
